# %%
#Import Pandas
import pandas as pd
import seaborn as sns

# %%
#Define the dataset in a dataframe
dataset = pd.read_csv("nyc-rolling-sales.csv")

#List headings so that we can copy them and change them easily
list(dataset.columns.values)
# Out:
# ['Unnamed: 0',
#  'BOROUGH',
#  'NEIGHBORHOOD',
#  'BUILDING CLASS CATEGORY',
#  'TAX CLASS AT PRESENT',
#  'BLOCK',
#  'LOT',
#  'EASE-MENT',
#  'BUILDING CLASS AT PRESENT',
#  'ADDRESS',
#  'APARTMENT NUMBER',
#  'ZIP CODE',
#  'RESIDENTIAL UNITS',
#  'COMMERCIAL UNITS',
#  'TOTAL UNITS',
#  'LAND SQUARE FEET',
#  'GROSS SQUARE FEET',
#  'YEAR BUILT',
#  'TAX CLASS AT TIME OF SALE',
#  'BUILDING CLASS AT TIME OF SALE',
#  'SALE PRICE',
#  'SALE DATE']

# %%
#Rename the columns of the dataset
dataset.columns = ['INDEX',
 'BOROUGH',
 'NEIGHBORHOOD',
 'BUILDING_CLASS_CATEGORY',
 'TAX_CLASS_AT_PRESENT',
 'BLOCK',
 'LOT',
 'EASE-MENT',
 'BUILDING_CLASS_AT_PRESENT',
 'ADDRESS',
 'APARTMENT_NUMBER',
 'ZIP_CODE',
 'RESIDENTIAL_UNITS',
 'COMMERCIAL_UNITS',
 'TOTAL_UNITS',
 'LAND_SQUARE_FEET',
 'GROSS_SQUARE_FEET',
 'YEAR_BUILT',
 'TAX_CLASS_AT_TIME_OF_SALE',
 'BUILDING_CLASS_AT_TIME_OF_SALE',
 'SALE_PRICE',
 'SALE_DATE']
list(dataset.columns.values)
# Out:
# ['INDEX',
#  'BOROUGH',
#  'NEIGHBORHOOD',
#  'BUILDING_CLASS_CATEGORY',
#  'TAX_CLASS_AT_PRESENT',
#  'BLOCK',
#  'LOT',
#  'EASE-MENT',
#  'BUILDING_CLASS_AT_PRESENT',
#  'ADDRESS',
#  'APARTMENT_NUMBER',
#  'ZIP_CODE',
#  'RESIDENTIAL_UNITS',
#  'COMMERCIAL_UNITS',
#  'TOTAL_UNITS',
#  'LAND_SQUARE_FEET',
#  'GROSS_SQUARE_FEET',
#  'YEAR_BUILT',
#  'TAX_CLASS_AT_TIME_OF_SALE',
#  'BUILDING_CLASS_AT_TIME_OF_SALE',
#  'SALE_PRICE',
#  'SALE_DATE']

# %%
#Check the data table
dataset.head (100)
# Out:
#     INDEX  BOROUGH   NEIGHBORHOOD  \
# 0       4        1  ALPHABET CITY
# 1       5        1  ALPHABET CITY
# 2       6        1  ALPHABET CITY
# 3       7        1  ALPHABET CITY
# 4       8        1  ALPHABET CITY
# 5       9        1  ALPHABET CITY
# 6      10        1  ALPHABET CITY
# 7      11        1  ALPHABET CITY
# 8      12        1  ALPHABET CITY
# 9      13        1  ALPHABET CITY
# 10     14        1  ALPHABET CITY
# 11     15        1  ALPHABET CITY
# 12     16        1  ALPHABET CITY
# 13     17        1  ALPHABET CITY
# 14     18        1  ALPHABET CITY
# 15     19        1  ALPHABET CITY
# 16     20        1  ALPHABET CITY
# 17     21        1  ALPHABET CITY
# 18     22        1  ALPHABET CITY
# 19     23        1  ALPHABET CITY
# 20     24        1  ALPHABET CITY
# 21     25        1  ALPHABET CITY
# 22     26        1  ALPHABET CITY
# 23     27        1  ALPHABET CITY
# 24     28        1  ALPHABET CITY
# 25     29        1  ALPHABET CITY
# ...

# %%
#Remove all rows of data that have blank values for either, "SALE PRICE", "LAND SQUARE FEET" or "GROSS SQUARE FEET"
dataset = dataset[dataset.SALE_PRICE != " -  "]
dataset = dataset[dataset.GROSS_SQUARE_FEET != " -  "]
dataset = dataset[dataset.LAND_SQUARE_FEET != " -  "]
dataset.head(100)
# Out:
#       INDEX  BOROUGH   NEIGHBORHOOD  \
# 0         4        1  ALPHABET CITY
# 3         7        1  ALPHABET CITY
# 4         8        1  ALPHABET CITY
# 6        10        1  ALPHABET CITY
# 9        13        1  ALPHABET CITY
# 11       15        1  ALPHABET CITY
# 22       26        1  ALPHABET CITY
# 172     176        1  ALPHABET CITY
# 173     177        1  ALPHABET CITY
# 174     178        1  ALPHABET CITY
# 195     199        1  ALPHABET CITY
# 206     210        1        CHELSEA
# 207     211        1        CHELSEA
# 208     212        1        CHELSEA
# 209     213        1        CHELSEA
# 212     216        1        CHELSEA
# 214     218        1        CHELSEA
# 216     220        1        CHELSEA
# 218     222        1        CHELSEA
# 219     223        1        CHELSEA
# 220     224        1        CHELSEA
# 221     225        1        CHELSEA
# 222     226        1        CHELSEA
# 223     227        1        CHELSEA
# 224     228        1        CHELSEA
# ...

# %%
#Change the format of the cell value into an integer for key data fields
dataset.SALE_PRICE = dataset.SALE_PRICE.astype(int)
dataset.LAND_SQUARE_FEET = dataset.LAND_SQUARE_FEET.astype(int)
dataset.GROSS_SQUARE_FEET = dataset.GROSS_SQUARE_FEET.astype(int)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48244 entries, 0 to 84547
# Data columns (total 22 columns):
# INDEX                             48244 non-null int64
# BOROUGH                           48244 non-null int64
# NEIGHBORHOOD                      48244 non-null object
# BUILDING_CLASS_CATEGORY           48244 non-null object
# TAX_CLASS_AT_PRESENT              48244 non-null object
# BLOCK                             48244 non-null int64
# LOT                               48244 non-null int64
# EASE-MENT                         48244 non-null object
# BUILDING_CLASS_AT_PRESENT         48244 non-null object
# ADDRESS                           48244 non-null object
# APARTMENT_NUMBER                  48244 non-null object
# ZIP_CODE                          48244 non-null int64
# RESIDENTIAL_UNITS                 48244 non-null int64
# COMMERCIAL_UNITS                  48244 non-null int64
# TOTAL_UNITS                       48244 non-null int64
# ...

# %%
#View basic statistics/detail on the data table
dataset.describe()
# Out:
#               INDEX       BOROUGH         BLOCK           LOT      ZIP_CODE  \
# count  48244.000000  48244.000000  48244.000000  48244.000000  48244.000000
# mean   10448.940511      3.251741   4984.532191    234.324662  10939.681328
# std     7574.416359      0.903136   3427.418090    496.361521   1072.752086
# min        4.000000      1.000000      1.000000      1.000000      0.000000
# 25%     3919.750000      3.000000   2206.750000     21.000000  10469.000000
# 50%     8084.000000      3.000000   4660.500000     45.000000  11217.000000
# 75%    17160.000000      4.000000   6996.000000     94.000000  11237.000000
# max    26702.000000      5.000000  16319.000000   9009.000000  11694.000000
#
#        RESIDENTIAL_UNITS  COMMERCIAL_UNITS   TOTAL_UNITS  LAND_SQUARE_FEET  \
# count       48244.000000      48244.000000  48244.000000      4.824400e+04
# mean            2.566537          0.249171      2.834632      3.358117e+03
# ...

# %%
#List headings so that we can copy them and change them easily
list(dataset.columns.values)
# Out:
# ['INDEX',
#  'BOROUGH',
#  'NEIGHBORHOOD',
#  'BUILDING_CLASS_CATEGORY',
#  'TAX_CLASS_AT_PRESENT',
#  'BLOCK',
#  'LOT',
#  'EASE-MENT',
#  'BUILDING_CLASS_AT_PRESENT',
#  'ADDRESS',
#  'APARTMENT_NUMBER',
#  'ZIP_CODE',
#  'RESIDENTIAL_UNITS',
#  'COMMERCIAL_UNITS',
#  'TOTAL_UNITS',
#  'LAND_SQUARE_FEET',
#  'GROSS_SQUARE_FEET',
#  'YEAR_BUILT',
#  'TAX_CLASS_AT_TIME_OF_SALE',
#  'BUILDING_CLASS_AT_TIME_OF_SALE',
#  'SALE_PRICE',
#  'SALE_DATE']

# %%
dataset.columns = ['INDEX',
 'BOROUGH',
 'NEIGHBORHOOD',
 'BUILDING_CLASS_CATEGORY',
 'TAX_CLASS_AT_PRESENT',
 'BLOCK',
 'LOT',
 'EASE-MENT',
 'BUILDING_CLASS_AT_PRESENT',
 'ADDRESS',
 'APARTMENT_NUMBER',
 'ZIP_CODE',
 'RESIDENTIAL_UNITS',
 'COMMERCIAL_UNITS',
 'TOTAL_UNITS',
 'LAND_SQUARE_FEET',
 'GROSS_SQUARE_FEET',
 'YEAR_BUILT',
 'TAX_CLASS_AT_TIME_OF_SALE',
 'BUILDING_CLASS_AT_TIME_OF_SALE',
 'SALE_PRICE',
 'SALE_DATE']

# %%
list(dataset.columns.values)
# Out:
# ['INDEX',
#  'BOROUGH',
#  'NEIGHBORHOOD',
#  'BUILDING_CLASS_CATEGORY',
#  'TAX_CLASS_AT_PRESENT',
#  'BLOCK',
#  'LOT',
#  'EASE-MENT',
#  'BUILDING_CLASS_AT_PRESENT',
#  'ADDRESS',
#  'APARTMENT_NUMBER',
#  'ZIP_CODE',
#  'RESIDENTIAL_UNITS',
#  'COMMERCIAL_UNITS',
#  'TOTAL_UNITS',
#  'LAND_SQUARE_FEET',
#  'GROSS_SQUARE_FEET',
#  'YEAR_BUILT',
#  'TAX_CLASS_AT_TIME_OF_SALE',
#  'BUILDING_CLASS_AT_TIME_OF_SALE',
#  'SALE_PRICE',
#  'SALE_DATE']

# %%
dataset.GROSS_SQUARE_FEET
# Out:
# 0         6440
# 3         6794
# 4         4615
# 6         4226
# 9        18523
# 11       12350
# 22       16776
# 172       3360
# 173       5608
# 174       3713
# 195       3586
# 206       3855
# 207       5653
# 208       5653
# 209       5653
# 212       4978
# 214       3725
# 216       3762
# 218       2890
# 219       4500
# 220       3042
# 221      13056
# 222       6330
# 223       6330
# 224       6330
# 227       8540
# 230       7650
# 231       6335
# 232       5955
# 233       4100
#          ...
# 84510     1440
# 84511     1440
# 84512     3160
# 84514     2265
# 84516     2576
# 84517     1976
# 84518     3560
# 84519     2650
# 84520     2600
# 84521     2600
# 84522     2600
# 84526     1964
# 84527     1798
# 84528     1470
# 84529     2206
# 84530     2683
# 84531     2170
# 84532     2170
# 84533     2700
# 84534     2704
# 84535     2704
# 84536     2700
# 84537     2840
# 84540     1300
# 84541     2160
# 84543     2575
# 84544     2377
# ...

# %%
dataset.head(100)
# Out:
#       INDEX  BOROUGH   NEIGHBORHOOD  \
# 0         4        1  ALPHABET CITY
# 3         7        1  ALPHABET CITY
# 4         8        1  ALPHABET CITY
# 6        10        1  ALPHABET CITY
# 9        13        1  ALPHABET CITY
# 11       15        1  ALPHABET CITY
# 22       26        1  ALPHABET CITY
# 172     176        1  ALPHABET CITY
# 173     177        1  ALPHABET CITY
# 174     178        1  ALPHABET CITY
# 195     199        1  ALPHABET CITY
# 206     210        1        CHELSEA
# 207     211        1        CHELSEA
# 208     212        1        CHELSEA
# 209     213        1        CHELSEA
# 212     216        1        CHELSEA
# 214     218        1        CHELSEA
# 216     220        1        CHELSEA
# 218     222        1        CHELSEA
# 219     223        1        CHELSEA
# 220     224        1        CHELSEA
# 221     225        1        CHELSEA
# 222     226        1        CHELSEA
# 223     227        1        CHELSEA
# 224     228        1        CHELSEA
# ...

# %%
#Use Matplotlib in order to start visualising correlations
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
x = dataset.GROSS_SQUARE_FEET
y = dataset.SALE_PRICE
plt.scatter(x, y)
plt.show()

# %%
corr = dataset.corr()
sns.heatmap(corr)

# %%
#Identify how many zero values there are for SALE PRICE
print (dataset.SALE_PRICE[dataset.SALE_PRICE == 0].count())
# Out:
# 10228

# %%
#Remove the 10,228 rows with 0 SALE PRICE
dataset = dataset[dataset.SALE_PRICE!=0]

# %%
dataset.count()
# Out:
# INDEX                             38016
# BOROUGH                           38016
# NEIGHBORHOOD                      38016
# BUILDING_CLASS_CATEGORY           38016
# TAX_CLASS_AT_PRESENT              38016
# BLOCK                             38016
# LOT                               38016
# EASE-MENT                         38016
# BUILDING_CLASS_AT_PRESENT         38016
# ADDRESS                           38016
# APARTMENT_NUMBER                  38016
# ZIP_CODE                          38016
# RESIDENTIAL_UNITS                 38016
# COMMERCIAL_UNITS                  38016
# TOTAL_UNITS                       38016
# LAND_SQUARE_FEET                  38016
# GROSS_SQUARE_FEET                 38016
# YEAR_BUILT                        38016
# TAX_CLASS_AT_TIME_OF_SALE         38016
# BUILDING_CLASS_AT_TIME_OF_SALE    38016
# SALE_PRICE                        38016
# SALE_DATE                         38016
# dtype: int64

# %%
#Re-run the correlation between SALE PRICE and GROSS SQUARE FEET
# %matplotlib inline
matplotlib.style.use('ggplot')
x = dataset.GROSS_SQUARE_FEET
y = dataset.SALE_PRICE
plt.scatter(x, y)
plt.show()

# %%
dataset['GROSS_SQUARE_FEET'].min()
# Out:
# 0

# %%
#Identify how many zero values there are for GROSS_SQUARE_FEET
print (dataset.GROSS_SQUARE_FEET[dataset.GROSS_SQUARE_FEET == 0].count())
# Out:
# 8686

# %%
#Remove the 8,686 rows with 0 GROSS SQUARE FEET
dataset = dataset[dataset.GROSS_SQUARE_FEET!=0]

# %%
dataset.count()
# Out:
# INDEX                             29330
# BOROUGH                           29330
# NEIGHBORHOOD                      29330
# BUILDING_CLASS_CATEGORY           29330
# TAX_CLASS_AT_PRESENT              29330
# BLOCK                             29330
# LOT                               29330
# EASE-MENT                         29330
# BUILDING_CLASS_AT_PRESENT         29330
# ADDRESS                           29330
# APARTMENT_NUMBER                  29330
# ZIP_CODE                          29330
# RESIDENTIAL_UNITS                 29330
# COMMERCIAL_UNITS                  29330
# TOTAL_UNITS                       29330
# LAND_SQUARE_FEET                  29330
# GROSS_SQUARE_FEET                 29330
# YEAR_BUILT                        29330
# TAX_CLASS_AT_TIME_OF_SALE         29330
# BUILDING_CLASS_AT_TIME_OF_SALE    29330
# SALE_PRICE                        29330
# SALE_DATE                         29330
# dtype: int64

# %%
#Re-run the correlation between SALE PRICE and GROSS SQUARE FEET
# %matplotlib inline
matplotlib.style.use('ggplot')
x = dataset.GROSS_SQUARE_FEET
y = dataset.SALE_PRICE
plt.scatter(x, y)
plt.show()

# %%
dataset["GROSS_SQUARE_FEET"].idxmax()
# Out:
# 61460

# %%
dataset.loc[[61460]]
# Out:
#        INDEX  BOROUGH NEIGHBORHOOD  \
# 61460  12062        4    GLEN OAKS
#
#                            BUILDING_CLASS_CATEGORY TAX_CLASS_AT_PRESENT  \
# 61460  10 COOPS - ELEVATOR APARTMENTS                                 2
#
#        BLOCK  LOT EASE-MENT BUILDING_CLASS_AT_PRESENT  \
# 61460   8489    1                                  D4
#
#                           ADDRESS         ...          RESIDENTIAL_UNITS  \
# 61460  26910 GRAND CENTRAL PARKWA         ...                       1844
#
#        COMMERCIAL_UNITS  TOTAL_UNITS  LAND_SQUARE_FEET  GROSS_SQUARE_FEET  \
# 61460                22         1866           4228300            3750565
#
#        YEAR_BUILT  TAX_CLASS_AT_TIME_OF_SALE  BUILDING_CLASS_AT_TIME_OF_SALE  \
# 61460        1972                          2                              D4
#
#        SALE_PRICE            SALE_DATE
# 61460      525000  2017-07-05 00:00:00
#
# [1 rows x 22 columns]

# %%
df = dataset.drop(61460)

# %%
df["GROSS_SQUARE_FEET"].idxmax()
# Out:
# 2559

# %%
#Re-run the correlation between SALE PRICE and GROSS SQUARE FEET
# %matplotlib inline
matplotlib.style.use('ggplot')
x = df.GROSS_SQUARE_FEET
y = df.SALE_PRICE
plt.scatter(x, y)
plt.show()

# %%
df["SALE_PRICE"].idxmax()
# Out:
# 7447

# %%
dataset.loc[[7447]]
# Out:
#       INDEX  BOROUGH NEIGHBORHOOD  \
# 7447   7451        1  MIDTOWN CBD
#
#                           BUILDING_CLASS_CATEGORY TAX_CLASS_AT_PRESENT  BLOCK  \
# 7447  21 OFFICE BUILDINGS                                            4   1301
#
#       LOT EASE-MENT BUILDING_CLASS_AT_PRESENT          ADDRESS  \
# 7447    1                                  O4  245 PARK AVENUE
#
#              ...          RESIDENTIAL_UNITS  COMMERCIAL_UNITS  TOTAL_UNITS  \
# 7447         ...                          0                35           35
#
#       LAND_SQUARE_FEET  GROSS_SQUARE_FEET  YEAR_BUILT  \
# 7447             81336            1586886        1966
#
#       TAX_CLASS_AT_TIME_OF_SALE  BUILDING_CLASS_AT_TIME_OF_SALE  SALE_PRICE  \
# 7447                          4                              O4  2210000000
#
#                 SALE_DATE
# 7447  2017-05-05 00:00:00
#
# [1 rows x 22 columns]

# %%
#Create a column that calculates price per square foot for each property
df['Price_per_sqft'] = df['SALE_PRICE']/df['GROSS_SQUARE_FEET']

# %%
df.head(5)
# Out:
#    INDEX  BOROUGH   NEIGHBORHOOD                      BUILDING_CLASS_CATEGORY  \
# 0      4        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3      7        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4      8        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 6     10        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 9     13        1  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
#
#   TAX_CLASS_AT_PRESENT  BLOCK  LOT EASE-MENT BUILDING_CLASS_AT_PRESENT  \
# 0                   2A    392    6                                  C2
# 3                   2B    402   21                                  C4
# 4                   2A    404   55                                  C2
# 6                   2B    406   32                                  C4
# 9                    2    387  153                                  D9
#
#                   ADDRESS      ...       COMMERCIAL_UNITS  TOTAL_UNITS  \
# ...

# %%
#Calculate the average price per square foot, by Neighbourhood. Make this a dataset.
avgprice = df.groupby("NEIGHBORHOOD").mean()

# %%
avgprice.head(5)
# Out:
#                          INDEX  BOROUGH        BLOCK         LOT  \
# NEIGHBORHOOD
# AIRPORT LA GUARDIA    6.000000      4.0   965.200000   43.200000
# ALPHABET CITY        73.909091      1.0   394.090909   33.090909
# ANNADALE             86.409091      5.0  6280.972727   49.990909
# ARDEN HEIGHTS       326.364444      5.0  5897.026667  123.791111
# ARROCHAR            501.583333      5.0  3104.000000   49.000000
#
#                         ZIP_CODE  RESIDENTIAL_UNITS  COMMERCIAL_UNITS  \
# NEIGHBORHOOD
# AIRPORT LA GUARDIA  11370.000000           2.400000          0.000000
# ALPHABET CITY       10009.000000           9.000000          0.363636
# ANNADALE            10124.509091           1.318182          0.018182
# ARDEN HEIGHTS       10312.000000           1.137778          0.004444
# ARROCHAR            10305.000000           1.416667          0.125000
#
#                     TOTAL_UNITS  LAND_SQUARE_FEET  GROSS_SQUARE_FEET  \
# NEIGHBORHOOD
# ...

# %%
def plot_bar_x():
    plt.bar(avgprice.index, avgprice.SALE_PRICE)
    plt.xlabel('HOOD', fontsize=5)
    plt.ylabel('Avg. Price per Sqft.', fontsize=5)
    plt.xticks(avgprice.index, avgprice.SALE_PRICE, fontsize=5, rotation=30)
    plt.title('Average price per square foot of New York properties')
    plt.show()

# %%
plot_bar_x()

# %%
avgprice.BOROUGH
# Out:
# NEIGHBORHOOD
# AIRPORT LA GUARDIA          4.0
# ALPHABET CITY               1.0
# ANNADALE                    5.0
# ARDEN HEIGHTS               5.0
# ARROCHAR                    5.0
# ARROCHAR-SHORE ACRES        5.0
# ARVERNE                     4.0
# ASTORIA                     4.0
# BATH BEACH                  3.0
# BATHGATE                    2.0
# BAY RIDGE                   3.0
# BAYCHESTER                  2.0
# BAYSIDE                     4.0
# BEDFORD PARK/NORWOOD        2.0
# BEDFORD STUYVESANT          3.0
# BEECHHURST                  4.0
# BELLE HARBOR                4.0
# BELLEROSE                   4.0
# BELMONT                     2.0
# BENSONHURST                 3.0
# BERGEN BEACH                3.0
# BOERUM HILL                 3.0
# BOROUGH PARK                3.0
# BRIARWOOD                   4.0
# BRIGHTON BEACH              3.0
# BROAD CHANNEL               4.0
# BRONX PARK                  2.0
# BRONXDALE                   2.0
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import seaborn as sns
import statsmodels.formula.api as smf
# Suppress depreciation warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
subset = df[df['BOROUGH']==2]
subset.shape
# Out:
# (3512, 23)

# %%
X = subset[['SALE_PRICE']]
y = subset[['GROSS_SQUARE_FEET']]
X_train, X_test, y_train, y_test=train_test_split(X, y, 
                                                  test_size = 0.25,
                                                  random_state = 123)

# %%
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (2634, 1) (2634, 1)
# (878, 1) (878, 1)

# %%
Train = pd.concat([X_train, y_train], axis=1)
r = sns.regplot(x= 'SALE_PRICE', y='GROSS_SQUARE_FEET', data=Train)

# %%
for borough in range(1,6):
    subset = df[df['BOROUGH']== borough]
    subset.shape
    X = subset[['SALE_PRICE']]
    y = subset[['GROSS_SQUARE_FEET']]
    X_train, X_test, y_train, y_test=train_test_split(X, y, 
                                                  test_size = 0.25,
                                                  random_state = 123)
    Train = pd.concat([X_train, y_train], axis=1)
    plt.figure(borough)
    r = sns.regplot(x= 'SALE_PRICE', y='GROSS_SQUARE_FEET', data=Train)

# %%
dict = {'BOROUGH':[1,2,3,4,5,], "Borough_label":["Manhattan","Brooklyn","Queens", "Bronx","Staten Island"]}
df2 = pd.DataFrame.from_dict(dict)
df3 = pd.merge(df,df2, on=['BOROUGH'], how='inner')

# %%
for borough in range(1,6):
    subset = df[df['BOROUGH']== borough]
    subset.shape
    X = subset[['SALE_PRICE']]
    y = subset[['GROSS_SQUARE_FEET']]
    X_train, X_test, y_train, y_test=train_test_split(X, y, 
                                                  test_size = 0.25,
                                                  random_state = 123)
# Create linear regression object
    regression_model = linear_model.LinearRegression()

# Train the model using the training sets
    regression_model= regression_model.fit(X_train, y_train)
# The R-squared
    print("The R-squared for %s is %s" % (df2[df2['BOROUGH'] == borough].iloc[0]['Borough_label'], regression_model.score(X_train, y_train)))
    Train = pd.concat([X_train, y_train], axis=1)
    plt.figure(borough)
    r = sns.regplot(x= 'SALE_PRICE', y='GROSS_SQUARE_FEET', data=Train)
# Out:
# The R-squared for Manhattan is 0.28412178963668655
# The R-squared for Brooklyn is 0.4993762937524886
# The R-squared for Queens is 0.16890106936176863
# The R-squared for Bronx is 0.5826658220553365
# The R-squared for Staten Island is 0.03847636467397131

# %%
df2
# Out:
#    BOROUGH  Borough_label
# 0        1      Manhattan
# 1        2       Brooklyn
# 2        3         Queens
# 3        4          Bronx
# 4        5  Staten Island

# %%
dict_borough = {1:"Manhattan", 2:"brooklyn", 3:"Queens", 4:"Bronx", 5:"Staten Island"}

# %%
dict_borough
# Out:
# {1: 'Manhattan', 2: 'brooklyn', 3: 'Queens', 4: 'Bronx', 5: 'Staten Island'}

# %%
df_borough = pd.DataFrame.from_dict({1:"Manhattan", 2:"brooklyn", 3:"Queens", 4:"Bronx", 5:"Staten Island"}, 
                                    index= [0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-5d3de76d853b> in <module>()
#       1 df_borough = pd.DataFrame.from_dict({1:"Manhattan", 2:"brooklyn", 3:"Queens", 4:"Bronx", 5:"Staten Island"},
# ----> 2                                     index= [0])
#
# TypeError: from_dict() got an unexpected keyword argument 'index'
